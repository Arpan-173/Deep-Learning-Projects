# %% [markdown]
# # Jigsaw puzzle
#
# The task is to reconstruct a complete RGB image of size 96×96 from a set of 9 scrambled image patches of size 28×28×3. The patches originate from a 3×3 partition of the original image, but their spatial arrangement is unknown and part of the border information has been removed through erosion, making the reconstruction problem ambiguous. The model must therefore infer both the correct relative placement of the patches and the missing visual content required to produce a coherent, artifact-free reconstruction of the original image.

# %%
import os
import numpy as np
import keras
from keras import layers, models
from keras.utils import PyDataset
import tensorflow as tf
import random

SEED = 42

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# We use the stanford stl10 dataset, containng 100K color images at resolution (96,96), covering 10 classes: airplane, bird, car, cat, deer, dog, horse, monkey, ship, truck.
#
# Downloading the dataset is time consuming. We recommend to save a local copy.

# %%
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.utils import PyDataset

def get_stl10_memmap():
    path = tf.keras.utils.get_file(
        'stl10_binary.tar.gz',
        origin='http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz',
        extract=True
    )
    base_dir = os.path.dirname(path)
    filepath = os.path.join(base_dir, 'stl10_binary_extracted', 'stl10_binary', 'unlabeled_X.bin')

    # STL-10: 100,000 images, 3 channels, 96x96
    # We use memmap to avoid loading the file into RAM
    # Shape is (N, C, H, W) based on STL-10 binary format
    shape = (100000, 3, 96, 96)
    images_mmap = np.memmap(filepath, dtype='uint8', mode='r', shape=shape)

    return images_mmap

class PatchGenerator(PyDataset):
    def __init__(self, images_mmap, batch_size=32, patch_size=32, crop_size=28, shuffle=True, **kwargs):
        super().__init__(**kwargs)
        # Store the pointer to the memmap, keep it as uint8
        self.images = images_mmap
        self.batch_size = batch_size
        self.patch_size = patch_size
        self.crop_size = crop_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.images))
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, idx):
        batch_indices = self.indices[idx * self.batch_size : (idx + 1) * self.batch_size]
        actual_batch_size = len(batch_indices)

        X = np.zeros((actual_batch_size, 9, self.crop_size, self.crop_size, 3), dtype="float32")
        Y = np.zeros((actual_batch_size, 96, 96, 3), dtype="float32")
        Y_order = np.zeros((actual_batch_size, 9), dtype="float32")
        for i, img_idx in enumerate(batch_indices):
            # 1. Load from disk/cache only what we need
            # 2. Transpose from (C, H, W) to (H, W, C)
            # 3. Convert to float and normalize ONLY this one image
            img_cxhxw = self.images[img_idx]
            full_img = img_cxhxw.transpose(2, 1, 0).astype("float32") / 255.0

            Y[i] = full_img

            # Patch extraction logic
            patches = []
            for r in range(3):
                for c in range(3):
                    y_s, x_s = r * self.patch_size, c * self.patch_size
                    patch = full_img[y_s:y_s+self.patch_size, x_s:x_s+self.patch_size, :]

                    margin = (self.patch_size - self.crop_size) // 2
                    patch = patch[margin:margin+self.crop_size, margin:margin+self.crop_size, :]
                    patches.append(patch)

            order = np.random.permutation(9)
            Y_order[i] = order.astype("float32")
            for slot_idx, original_pos in enumerate(order):
                X[i, slot_idx] = patches[original_pos]

        return X, {
            'reconstruction': Y,
            'ordering': Y_order
        }

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
# Trigger the download and loading
images = get_stl10_memmap()
print(f"Successfully downloaded and memory mapped {images.shape[0]} images.")
# Out:
# Downloading data from http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz
# 2640397119/2640397119 ━━━━━━━━━━━━━━━━━━━━ 389s 0us/step
# Successfully downloaded and memory mapped 100000 images.

# %%
print(images.shape)
# Out:
# (100000, 3, 96, 96)

# %%
train_images = images[:80000]
val_images = images[80000:90000]
test_images = images[90000:]

# %%
train_generator = PatchGenerator(train_images, batch_size=64)
val_generator = PatchGenerator(val_images, batch_size=64)
test_generator = PatchGenerator(test_images, batch_size=64)

# %% [markdown]
# Let us inspect the dataset.

# %%
import matplotlib.pyplot as plt
n = np.random.randint(0,test_images.shape[0])
plt.imshow(np.transpose(test_images[n],(2,1,0)))

# %% [markdown]
# Let us now visualize the puzzle

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_puzzle(patches, ordering=None):
    """
    Plots jigsaw patches on a 96x96 canvas.

    Args:
        patches: Array of shape (9, 28, 28, 3)
        ordering: Optional array of shape (9,) or (1, 9) containing
                  the destination grid indices.
    """
    # 1. Handle ordering: if None, use [0, 1, 2... 8]
    if ordering is None:
        order = np.arange(9)
    else:
        order = np.array(ordering).flatten()

    # 2. Setup canvas (96x96x3)
    # Use 1.0 for float images (0.0-1.0) or 255 for uint8 images
    if patches.dtype == np.uint8:
        canvas = np.full((96, 96, 3), 255, dtype=np.uint8)
    else:
        canvas = np.ones((96, 96, 3), dtype=np.float32)

    cell_dim = 32
    patch_dim = 28
    margin = (cell_dim - patch_dim) // 2

    # 3. Place patches
    for i in range(9):
        # Determine destination grid position
        grid_pos = order[i]

        row = grid_pos // 3
        col = grid_pos % 3

        # Calculate canvas pixel coordinates
        y_start = (row * cell_dim) + margin
        y_end = y_start + patch_dim
        x_start = (col * cell_dim) + margin
        x_end = x_start + patch_dim

        # Insert patch i into its grid_pos
        canvas[y_start:y_end, x_start:x_end] = patches[i]

    # 4. Display
    plt.figure(figsize=(5, 5))
    plt.imshow(canvas)
    plt.axis('off')
    plt.show()

# %%
a,b = test_generator.__getitem__(1)

# %%
plt.imshow(b['reconstruction'][4])

# %%
plot_puzzle(a[4])

# %% [markdown]
# # The problem
#
# Your task is to reconstruct the source (96,96) image from the set of 9 scambled patches of dimension (28,28) each.
#
# **The metric used to measure the quality of the reconstruction must be Mean Absolute Error (MAE).**
#
# Compute MAE over the test set, and also return the standard deviation.

# %% [markdown]
# As an indicative baseline, let us compute the MAE relative to the mean patches.

# %% [markdown]
# Methodology

# %%
#  Stage 1a: shared patch encoder

def build_patch_encoder(embed_dim=128):
    """
    CNN: (28, 28, 3) → (embed_dim,)
    Shared weights across all 9 patches via TimeDistributed.
    """
    inp = layers.Input(shape=(28, 28, 3))

    x = layers.Conv2D(32, 3, padding='same')(inp)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(32, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)                    # 14×14

    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(2)(x)                    # 7×7

    x = layers.Conv2D(128, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(embed_dim, activation='relu')(x)
    x = layers.LayerNormalization()(x)

    return models.Model(inp, x, name='patch_encoder')


# ── Stage 1b: transformer ordering network

def build_ordering_network(embed_dim=128, num_heads=4,
                           ff_dim=256, num_layers=3):
    patches_input = layers.Input(shape=(9, 28, 28, 3), name='patches')

    patch_encoder = build_patch_encoder(embed_dim)
    x = layers.TimeDistributed(
        patch_encoder, name='shared_encoder')(patches_input)  # (B, 9, 128)

    for i in range(num_layers):
        x_norm   = layers.LayerNormalization(name=f'ln1_{i}')(x)
        attn_out = layers.MultiHeadAttention(
            num_heads = num_heads,
            key_dim   = embed_dim // num_heads,
            dropout   = 0.1,
            name      = f'mha_{i}'
        )(x_norm, x_norm)
        x = x + layers.Dropout(0.1, name=f'drop_a_{i}')(attn_out)

        x_norm = layers.LayerNormalization(name=f'ln2_{i}')(x)
        ff     = layers.Dense(ff_dim, activation='gelu', name=f'ff1_{i}')(x_norm)
        ff     = layers.Dropout(0.1, name=f'drop_f_{i}')(ff)
        ff     = layers.Dense(embed_dim, name=f'ff2_{i}')(ff)
        x      = x + ff

    x      = layers.LayerNormalization(name='final_ln')(x)
    logits = layers.Dense(9, name='position_logits')(x)   # (B, 9, 9)

    return models.Model(patches_input, logits, name='ordering_network')


# ── Stage 2: neural placement layer───────

class NeuralPlacementLayer(layers.Layer):

    def __init__(self, n_positions=9, patch_size=28,
                 canvas_size=96, **kwargs):
        super().__init__(**kwargs)
        self.n_positions = n_positions
        self.patch_size  = patch_size
        self.canvas_size = canvas_size

    def build(self, input_shape):

        # Learned temperature — controls assignment sharpness
        # softplus keeps it strictly positive; +1e-3 prevents collapse to 0
        self.log_temp = self.add_weight(
            name='log_temperature', shape=(),
            initializer=tf.constant_initializer(0.0),
            trainable=True)

        # Learned placement coordinates — initialized to 3×3 grid centers
        # in [-1, 1] (STN coordinate space), but fully trainable.
        # This is the direct neural replacement for pos//3 arithmetic.
        cell  = self.canvas_size / 3.0
        inits = []
        for p in range(self.n_positions):
            row = p // 3
            col = p % 3
            y = ((row * cell + cell / 2.0) / self.canvas_size) * 2.0 - 1.0
            x = ((col * cell + cell / 2.0) / self.canvas_size) * 2.0 - 1.0
            inits.append([y, x])
        # NOTE: pos//3 arithmetic used ONCE here to set initial weight values.
        # During every forward pass, only self.position_coords is used.

        self.position_coords = self.add_weight(
            name='position_coords', shape=(self.n_positions, 2),
            initializer=tf.constant_initializer(
                np.array(inits, dtype=np.float32)),
            trainable=True)

        # Learned scale — softplus(raw) + 0.15 ensures strictly positive
        # Initialized so softplus(x) + 0.15 ≈ 0.292 → x ≈ -1.94
        self.placement_scale = self.add_weight(
            name='placement_scale', shape=(self.n_positions,),
            initializer=tf.constant_initializer([-1.94] * self.n_positions),
            trainable=True)

        super().build(input_shape)

    def _assign(self, logits):

        temp   = tf.math.softplus(self.log_temp) + 1e-3
        scaled = logits / temp

        # Row softmax: each patch sums to 1 across positions
        p_row = tf.nn.softmax(scaled, axis=-1)
        # Col softmax: each position sums to 1 across patches
        p_col = tf.nn.softmax(scaled, axis=-2)

        # Element-wise product penalises duplicate assignments
        w = p_row * p_col

        # Re-normalise rows so canvas mixing weights sum to 1
        assignment = w / (tf.reduce_sum(w, axis=-1, keepdims=True) + 1e-8)
        return assignment

    def _bilinear_sample(self, img, grid):
        #Bilinear grid sampling — standard spatial transformer operation.#
        B     = tf.shape(img)[0]
        H_in  = tf.shape(img)[1]
        W_in  = tf.shape(img)[2]
        H_out = tf.shape(grid)[1]
        W_out = tf.shape(grid)[2]

        x = (grid[..., 0] + 1.0) * tf.cast(W_in - 1, tf.float32) / 2.0
        y = (grid[..., 1] + 1.0) * tf.cast(H_in - 1, tf.float32) / 2.0

        x0 = tf.cast(tf.floor(x), tf.int32)
        y0 = tf.cast(tf.floor(y), tf.int32)
        x1 = x0 + 1
        y1 = y0 + 1

        x0 = tf.clip_by_value(x0, 0, W_in - 1)
        x1 = tf.clip_by_value(x1, 0, W_in - 1)
        y0 = tf.clip_by_value(y0, 0, H_in - 1)
        y1 = tf.clip_by_value(y1, 0, H_in - 1)

        def gather(yi, xi):
            bidx = tf.tile(
                tf.reshape(tf.range(B), (-1, 1, 1)), (1, H_out, W_out))
            return tf.gather_nd(img, tf.stack([bidx, yi, xi], axis=-1))

        Ia = gather(y0, x0);  Ib = gather(y1, x0)
        Ic = gather(y0, x1);  Id = gather(y1, x1)

        x0f = tf.cast(x0, tf.float32);  y0f = tf.cast(y0, tf.float32)
        x1f = tf.cast(x1, tf.float32);  y1f = tf.cast(y1, tf.float32)

        wa = tf.expand_dims((x1f - x)  * (y1f - y),  -1)
        wb = tf.expand_dims((x1f - x)  * (y  - y0f), -1)
        wc = tf.expand_dims((x  - x0f) * (y1f - y),  -1)
        wd = tf.expand_dims((x  - x0f) * (y  - y0f), -1)

        return wa*Ia + wb*Ib + wc*Ic + wd*Id

    def _place_patch(self, patch, y_c, x_c, scale):
        B = tf.shape(patch)[0]
        H = W = self.canvas_size

        gy = tf.linspace(-1.0, 1.0, H)
        gx = tf.linspace(-1.0, 1.0, W)
        grid_x, grid_y = tf.meshgrid(gx, gy)

        py = (grid_y - y_c) / (scale + 1e-8)
        px = (grid_x - x_c) / (scale + 1e-8)

        grid   = tf.stack([px, py], axis=-1)
        grid   = tf.tile(grid[None], [B, 1, 1, 1])
        placed = self._bilinear_sample(patch, grid)

        in_b = tf.cast(
            (tf.abs(py) <= 1.0) & (tf.abs(px) <= 1.0), tf.float32)
        mask = tf.tile(in_b[None, :, :, None], [B, 1, 1, 1])

        return placed, mask

    def call(self, inputs):
        logits, patches_raw = inputs

        assignment = self._assign(logits)           # (B, 9, 9)

        parts_canvas, parts_mask = [], []
        for pos_idx in range(self.n_positions):
            w        = assignment[:, :, pos_idx]
            w        = tf.reshape(w, (-1, 9, 1, 1, 1))
            composed = tf.reduce_sum(w * patches_raw, axis=1)

            # Learned coords — clipped to prevent patches leaving canvas
            y_c   = tf.clip_by_value(
                self.position_coords[pos_idx, 0], -1.2, 1.2)
            x_c   = tf.clip_by_value(
                self.position_coords[pos_idx, 1], -1.2, 1.2)
            scale = tf.math.softplus(
                self.placement_scale[pos_idx]) + 0.15

            placed, mask = self._place_patch(composed, y_c, x_c, scale)
            parts_canvas.append(placed)
            parts_mask.append(mask)

        canvas = tf.add_n(parts_canvas)
        mask   = tf.clip_by_value(tf.add_n(parts_mask), 0.0, 1.0)
        return tf.concat([canvas, mask], axis=-1), assignment

    def get_config(self):
        config = super().get_config()
        config.update({
            'n_positions': self.n_positions,
            'patch_size' : self.patch_size,
            'canvas_size': self.canvas_size,
        })
        return config


#  Stage 3: U-Net reconstruction network

def build_reconstruction_network():

    #U-Net: (96, 96, 4) → (96, 96, 3)
    #Input channel 4 = RGB canvas + binary mask.
    #Completely unchanged from original V2.

    inp = layers.Input(shape=(96, 96, 4), name='canvas_with_mask')

    def conv_block(x, filters, name):
        x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_c1')(x)
        x = layers.BatchNormalization(name=f'{name}_bn1')(x)
        x = layers.Activation('relu', name=f'{name}_r1')(x)
        x = layers.Conv2D(filters, 3, padding='same', name=f'{name}_c2')(x)
        x = layers.BatchNormalization(name=f'{name}_bn2')(x)
        x = layers.Activation('relu', name=f'{name}_r2')(x)
        return x

    e1 = conv_block(inp, 16,  'enc1')
    p1 = layers.MaxPooling2D(2, name='pool1')(e1)
    e2 = conv_block(p1,  32,  'enc2')
    p2 = layers.MaxPooling2D(2, name='pool2')(e2)
    e3 = conv_block(p2,  64,  'enc3')
    p3 = layers.MaxPooling2D(2, name='pool3')(e3)
    e4 = conv_block(p3,  128, 'enc4')
    p4 = layers.MaxPooling2D(2, name='pool4')(e4)
    b  = conv_block(p4,  192, 'bottleneck')

    d4 = layers.Conv2DTranspose(128, 2, strides=2, padding='same', name='up4')(b)
    d4 = layers.Concatenate(name='cat4')([d4, e4])
    d4 = conv_block(d4, 128, 'dec4')
    d3 = layers.Conv2DTranspose(64, 2, strides=2, padding='same', name='up3')(d4)
    d3 = layers.Concatenate(name='cat3')([d3, e3])
    d3 = conv_block(d3, 64, 'dec3')
    d2 = layers.Conv2DTranspose(32, 2, strides=2, padding='same', name='up2')(d3)
    d2 = layers.Concatenate(name='cat2')([d2, e2])
    d2 = conv_block(d2, 32, 'dec2')
    d1 = layers.Conv2DTranspose(16, 2, strides=2, padding='same', name='up1')(d2)
    d1 = layers.Concatenate(name='cat1')([d1, e1])
    d1 = conv_block(d1, 16, 'dec1')

    output = layers.Conv2D(3, 1, activation='sigmoid',
                           name='reconstruction')(d1)
    return models.Model(inp, output, name='reconstruction_network')


# ── Full pipeline ──────────────────

def build_full_pipeline():
    patches_input = layers.Input(shape=(9, 28, 28, 3), name='patches')

    # Stage 1: Transformer → logits (B, 9, 9)
    ordering_net = build_ordering_network()
    logits       = ordering_net(patches_input)

    # Stage 2: Neural assignment + learned placement → (B, 96, 96, 4)
    canvas_with_mask, assignment = NeuralPlacementLayer(
        name='neural_placement')([logits, patches_input])

    # Stage 3: U-Net inpainting → (B, 96, 96, 3)
    recon_net      = build_reconstruction_network()
    reconstruction = recon_net(canvas_with_mask)

    model = models.Model(
        inputs  = patches_input,
        outputs = {'reconstruction': reconstruction,
                   'ordering'      : assignment},
        name    = 'jigsaw_v2'
    )
    return model, ordering_net


def ordering_loss(y_true_positions, y_pred_assignment, smoothing=0.1):

    #Cross-entropy ordering loss with label smoothing.
    #Smoothing prevents overconfident assignments on training set,
    #which is the direct cause of the train/val ordering gap.

    depth = 9
    y_true_onehot = tf.one_hot(
        tf.cast(y_true_positions, tf.int32), depth=depth)

    # Smooth: blend one-hot with uniform distribution
    # smoothed = (1 - smoothing) * one_hot + smoothing / depth
    y_smooth = (1.0 - smoothing) * y_true_onehot + smoothing / depth

    ce = -tf.reduce_sum(
        y_smooth * tf.math.log(y_pred_assignment + 1e-8), axis=-1)
    return tf.reduce_mean(ce)


#  Build, verify, compile

model, ordering_net = build_full_pipeline()

# %% [markdown]
# Checking Model parameter

# %%
model.summary()

total = model.count_params()
# Out:
# Model: "jigsaw_v2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ patches             │ (None, 9, 28, 28, │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ordering_network    │ (None, 9, 9)      │    556,329 │ patches[0][0]     │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ neural_placement    │ [(None, 96, 96,   │         28 │ ordering_network… │
# │ (NeuralPlacementLa… │ 4), (None, 9, 9)] │            │ patches[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reconstruction_net… │ (None, 96, 96, 3) │  1,581,987 │ neural_placement… │
# │ (Functional)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,138,344 (8.16 MB)
#  Trainable params: 2,135,016 (8.14 MB)
#  Non-trainable params: 3,328 (13.00 KB)

# %%
model.compile(
    optimizer = keras.optimizers.Adam(
        learning_rate=1e-3,
        clipnorm=1.0
    ),
    loss = {
        'reconstruction': 'mae',
        'ordering'      : ordering_loss
    },
    loss_weights = {
        'reconstruction': 1.0,
        'ordering'      : 0.1   # auxiliary — reconstruction stays primary
    },
    metrics = {
        'reconstruction': keras.metrics.MeanAbsoluteError(name='mae')
    }
)

callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_reconstruction_mae', factor=0.5, patience=3, min_lr= 1e-6, mode= 'min', verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_reconstruction_mae', patience=5, restore_best_weights=True, mode='min', verbose=1),
    keras.callbacks.CSVLogger('training_log.csv')
]

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 319s 170ms/step - loss: 0.3010 - ordering_loss: 1.7324 - reconstruction_loss: 0.1278 - reconstruction_mae: 0.1278 - val_loss: 0.2829 - val_ordering_loss: 1.5944 - val_reconstruction_loss: 0.1235 - val_reconstruction_mae: 0.1235 - learning_rate: 0.0010
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.2503 - ordering_loss: 1.4646 - reconstruction_loss: 0.1039 - reconstruction_mae: 0.1039 - val_loss: 0.2362 - val_ordering_loss: 1.3738 - val_reconstruction_loss: 0.0987 - val_reconstruction_mae: 0.0987 - learning_rate: 0.0010
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.2277 - ordering_loss: 1.3425 - reconstruction_loss: 0.0935 - reconstruction_mae: 0.0935 - val_loss: 0.2185 - val_ordering_loss: 1.2800 - val_reconstruction_loss: 0.0904 - val_reconstruction_mae: 0.0904 - learning_rate: 0.0010
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.2134 - ordering_loss: 1.2647 - reconstruction_loss: 0.0869 - reconstruction_mae: 0.0869 - val_loss: 0.2066 - val_ordering_loss: 1.2269 - val_reconstruction_loss: 0.0837 - val_reconstruction_mae: 0.0838 - learning_rate: 0.0010
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.2021 - ordering_loss: 1.2038 - reconstruction_loss: 0.0817 - reconstruction_mae: 0.0817 - val_loss: 0.1916 - val_ordering_loss: 1.1385 - val_reconstruction_loss: 0.0779 - val_reconstruction_mae: 0.0778 - learning_rate: 0.0010
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 152ms/step - loss: 0.1931 - ordering_loss: 1.1552 - reconstruction_loss: 0.0776 - reconstruction_mae: 0.0776 - val_loss: 0.1873 - val_ordering_loss: 1.1260 - val_reconstruction_loss: 0.0748 - val_reconstruction_mae: 0.0748 - learning_rate: 0.0010
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1858 - ordering_loss: 1.1161 - reconstruction_loss: 0.0742 - reconstruction_mae: 0.0742 - val_loss: 0.1756 - val_ordering_loss: 1.0584 - val_reconstruction_loss: 0.0698 - val_reconstruction_mae: 0.0698 - learning_rate: 0.0010
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1797 - ordering_loss: 1.0844 - reconstruction_loss: 0.0712 - reconstruction_mae: 0.0712 - val_loss: 0.1854 - val_ordering_loss: 1.1187 - val_reconstruction_loss: 0.0735 - val_reconstruction_mae: 0.0735 - learning_rate: 0.0010
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1747 - ordering_loss: 1.0580 - reconstruction_loss: 0.0689 - reconstruction_mae: 0.0689 - val_loss: 0.1741 - val_ordering_loss: 1.0581 - val_reconstruction_loss: 0.0684 - val_reconstruction_mae: 0.0683 - learning_rate: 0.0010
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1699 - ordering_loss: 1.0339 - reconstruction_loss: 0.0665 - reconstruction_mae: 0.0665 - val_loss: 0.1667 - val_ordering_loss: 1.0081 - val_reconstruction_loss: 0.0658 - val_reconstruction_mae: 0.0659 - learning_rate: 0.0010
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1662 - ordering_loss: 1.0141 - reconstruction_loss: 0.0648 - reconstruction_mae: 0.0648 - val_loss: 0.1587 - val_ordering_loss: 0.9656 - val_reconstruction_loss: 0.0622 - val_reconstruction_mae: 0.0622 - learning_rate: 0.0010
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1632 - ordering_loss: 0.9991 - reconstruction_loss: 0.0633 - reconstruction_mae: 0.0633 - val_loss: 0.1637 - val_ordering_loss: 0.9822 - val_reconstruction_loss: 0.0653 - val_reconstruction_mae: 0.0654 - learning_rate: 0.0010
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1598 - ordering_loss: 0.9819 - reconstruction_loss: 0.0616 - reconstruction_mae: 0.0616 - val_loss: 0.1611 - val_ordering_loss: 0.9869 - val_reconstruction_loss: 0.0623 - val_reconstruction_mae: 0.0624 - learning_rate: 0.0010
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1573 - ordering_loss: 0.9682 - reconstruction_loss: 0.0605 - reconstruction_mae: 0.0605 - val_loss: 0.1527 - val_ordering_loss: 0.9329 - val_reconstruction_loss: 0.0594 - val_reconstruction_mae: 0.0594 - learning_rate: 0.0010
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1544 - ordering_loss: 0.9535 - reconstruction_loss: 0.0591 - reconstruction_mae: 0.0591 - val_loss: 0.1480 - val_ordering_loss: 0.9179 - val_reconstruction_loss: 0.0562 - val_reconstruction_mae: 0.0562 - learning_rate: 0.0010
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1518 - ordering_loss: 0.9406 - reconstruction_loss: 0.0577 - reconstruction_mae: 0.0577 - val_loss: 0.1484 - val_ordering_loss: 0.9166 - val_reconstruction_loss: 0.0566 - val_reconstruction_mae: 0.0566 - learning_rate: 0.0010
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1495 - ordering_loss: 0.9283 - reconstruction_loss: 0.0566 - reconstruction_mae: 0.0566 - val_loss: 0.1514 - val_ordering_loss: 0.9443 - val_reconstruction_loss: 0.0572 - val_reconstruction_mae: 0.0571 - learning_rate: 0.0010
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1476 - ordering_loss: 0.9185 - reconstruction_loss: 0.0558 - reconstruction_mae: 0.0558 - val_loss: 0.1464 - val_ordering_loss: 0.9034 - val_reconstruction_loss: 0.0559 - val_reconstruction_mae: 0.0560 - learning_rate: 0.0010
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1455 - ordering_loss: 0.9078 - reconstruction_loss: 0.0547 - reconstruction_mae: 0.0547 - val_loss: 0.1448 - val_ordering_loss: 0.9051 - val_reconstruction_loss: 0.0542 - val_reconstruction_mae: 0.0542 - learning_rate: 0.0010
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1442 - ordering_loss: 0.9014 - reconstruction_loss: 0.0541 - reconstruction_mae: 0.0541 - val_loss: 0.1447 - val_ordering_loss: 0.9010 - val_reconstruction_loss: 0.0547 - val_reconstruction_mae: 0.0546 - learning_rate: 0.0010
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1422 - ordering_loss: 0.8906 - reconstruction_loss: 0.0531 - reconstruction_mae: 0.0531 - val_loss: 0.1431 - val_ordering_loss: 0.8928 - val_reconstruction_loss: 0.0537 - val_reconstruction_mae: 0.0537 - learning_rate: 0.0010
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1407 - ordering_loss: 0.8836 - reconstruction_loss: 0.0524 - reconstruction_mae: 0.0524 - val_loss: 0.1443 - val_ordering_loss: 0.9031 - val_reconstruction_loss: 0.0539 - val_reconstruction_mae: 0.0540 - learning_rate: 0.0010
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1395 - ordering_loss: 0.8768 - reconstruction_loss: 0.0518 - reconstruction_mae: 0.0518 - val_loss: 0.1408 - val_ordering_loss: 0.8796 - val_reconstruction_loss: 0.0530 - val_reconstruction_mae: 0.0529 - learning_rate: 0.0010
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1381 - ordering_loss: 0.8690 - reconstruction_loss: 0.0512 - reconstruction_mae: 0.0512 - val_loss: 0.1393 - val_ordering_loss: 0.8762 - val_reconstruction_loss: 0.0518 - val_reconstruction_mae: 0.0518 - learning_rate: 0.0010
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1368 - ordering_loss: 0.8629 - reconstruction_loss: 0.0505 - reconstruction_mae: 0.0505 - val_loss: 0.1380 - val_ordering_loss: 0.8689 - val_reconstruction_loss: 0.0510 - val_reconstruction_mae: 0.0511 - learning_rate: 0.0010
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1352 - ordering_loss: 0.8544 - reconstruction_loss: 0.0497 - reconstruction_mae: 0.0497 - val_loss: 0.1384 - val_ordering_loss: 0.8608 - val_reconstruction_loss: 0.0523 - val_reconstruction_mae: 0.0523 - learning_rate: 0.0010
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1340 - ordering_loss: 0.8481 - reconstruction_loss: 0.0492 - reconstruction_mae: 0.0492 - val_loss: 0.1363 - val_ordering_loss: 0.8611 - val_reconstruction_loss: 0.0502 - val_reconstruction_mae: 0.0502 - learning_rate: 0.0010
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1331 - ordering_loss: 0.8436 - reconstruction_loss: 0.0488 - reconstruction_mae: 0.0488 - val_loss: 0.1376 - val_ordering_loss: 0.8650 - val_reconstruction_loss: 0.0512 - val_reconstruction_mae: 0.0512 - learning_rate: 0.0010
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1317 - ordering_loss: 0.8366 - reconstruction_loss: 0.0480 - reconstruction_mae: 0.0480 - val_loss: 0.1397 - val_ordering_loss: 0.8810 - val_reconstruction_loss: 0.0516 - val_reconstruction_mae: 0.0516 - learning_rate: 0.0010
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1299 - ordering_loss: 0.8249 - reconstruction_loss: 0.0474 - reconstruction_mae: 0.0474
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1308 - ordering_loss: 0.8318 - reconstruction_loss: 0.0476 - reconstruction_mae: 0.0476 - val_loss: 0.1383 - val_ordering_loss: 0.8658 - val_reconstruction_loss: 0.0516 - val_reconstruction_mae: 0.0516 - learning_rate: 0.0010
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 194s 155ms/step - loss: 0.1221 - ordering_loss: 0.7865 - reconstruction_loss: 0.0434 - reconstruction_mae: 0.0434 - val_loss: 0.1303 - val_ordering_loss: 0.8333 - val_reconstruction_loss: 0.0469 - val_reconstruction_mae: 0.0469 - learning_rate: 5.0000e-04
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1200 - ordering_loss: 0.7749 - reconstruction_loss: 0.0425 - reconstruction_mae: 0.0425 - val_loss: 0.1284 - val_ordering_loss: 0.8254 - val_reconstruction_loss: 0.0460 - val_reconstruction_mae: 0.0459 - learning_rate: 5.0000e-04
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1191 - ordering_loss: 0.7699 - reconstruction_loss: 0.0421 - reconstruction_mae: 0.0421 - val_loss: 0.1285 - val_ordering_loss: 0.8247 - val_reconstruction_loss: 0.0462 - val_reconstruction_mae: 0.0461 - learning_rate: 5.0000e-04
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1180 - ordering_loss: 0.7639 - reconstruction_loss: 0.0416 - reconstruction_mae: 0.0416 - val_loss: 0.1289 - val_ordering_loss: 0.8300 - val_reconstruction_loss: 0.0459 - val_reconstruction_mae: 0.0459 - learning_rate: 5.0000e-04
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.1164 - ordering_loss: 0.7552 - reconstruction_loss: 0.0409 - reconstruction_mae: 0.0409
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 189s 151ms/step - loss: 0.1173 - ordering_loss: 0.7610 - reconstruction_loss: 0.0412 - reconstruction_mae: 0.0412 - val_loss: 0.1291 - val_ordering_loss: 0.8278 - val_reconstruction_loss: 0.0462 - val_reconstruction_mae: 0.0462 - learning_rate: 5.0000e-04
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1128 - ordering_loss: 0.7367 - reconstruction_loss: 0.0391 - reconstruction_mae: 0.0391 - val_loss: 0.1267 - val_ordering_loss: 0.8214 - val_reconstruction_loss: 0.0446 - val_reconstruction_mae: 0.0446 - learning_rate: 2.5000e-04
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1117 - ordering_loss: 0.7303 - reconstruction_loss: 0.0387 - reconstruction_mae: 0.0387 - val_loss: 0.1276 - val_ordering_loss: 0.8278 - val_reconstruction_loss: 0.0448 - val_reconstruction_mae: 0.0448 - learning_rate: 2.5000e-04
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1112 - ordering_loss: 0.7280 - reconstruction_loss: 0.0384 - reconstruction_mae: 0.0384 - val_loss: 0.1263 - val_ordering_loss: 0.8174 - val_reconstruction_loss: 0.0445 - val_reconstruction_mae: 0.0445 - learning_rate: 2.5000e-04
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1108 - ordering_loss: 0.7256 - reconstruction_loss: 0.0382 - reconstruction_mae: 0.0382 - val_loss: 0.1254 - val_ordering_loss: 0.8094 - val_reconstruction_loss: 0.0443 - val_reconstruction_mae: 0.0444 - learning_rate: 2.5000e-04
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1103 - ordering_loss: 0.7228 - reconstruction_loss: 0.0380 - reconstruction_mae: 0.0380 - val_loss: 0.1259 - val_ordering_loss: 0.8165 - val_reconstruction_loss: 0.0441 - val_reconstruction_mae: 0.0442 - learning_rate: 2.5000e-04
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1100 - ordering_loss: 0.7215 - reconstruction_loss: 0.0378 - reconstruction_mae: 0.0378 - val_loss: 0.1253 - val_ordering_loss: 0.8138 - val_reconstruction_loss: 0.0438 - val_reconstruction_mae: 0.0439 - learning_rate: 2.5000e-04
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 189s 152ms/step - loss: 0.1095 - ordering_loss: 0.7185 - reconstruction_loss: 0.0376 - reconstruction_mae: 0.0376 - val_loss: 0.1257 - val_ordering_loss: 0.8161 - val_reconstruction_loss: 0.0440 - val_reconstruction_mae: 0.0440 - learning_rate: 2.5000e-04
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1091 - ordering_loss: 0.7171 - reconstruction_loss: 0.0374 - reconstruction_mae: 0.0374 - val_loss: 0.1253 - val_ordering_loss: 0.8161 - val_reconstruction_loss: 0.0436 - val_reconstruction_mae: 0.0436 - learning_rate: 2.5000e-04
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1088 - ordering_loss: 0.7152 - reconstruction_loss: 0.0373 - reconstruction_mae: 0.0373 - val_loss: 0.1259 - val_ordering_loss: 0.8197 - val_reconstruction_loss: 0.0439 - val_reconstruction_mae: 0.0439 - learning_rate: 2.5000e-04
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 194s 155ms/step - loss: 0.1085 - ordering_loss: 0.7136 - reconstruction_loss: 0.0372 - reconstruction_mae: 0.0372 - val_loss: 0.1249 - val_ordering_loss: 0.8141 - val_reconstruction_loss: 0.0434 - val_reconstruction_mae: 0.0434 - learning_rate: 2.5000e-04
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1081 - ordering_loss: 0.7113 - reconstruction_loss: 0.0370 - reconstruction_mae: 0.0370 - val_loss: 0.1257 - val_ordering_loss: 0.8182 - val_reconstruction_loss: 0.0439 - val_reconstruction_mae: 0.0439 - learning_rate: 2.5000e-04
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1078 - ordering_loss: 0.7093 - reconstruction_loss: 0.0368 - reconstruction_mae: 0.0368 - val_loss: 0.1259 - val_ordering_loss: 0.8190 - val_reconstruction_loss: 0.0440 - val_reconstruction_mae: 0.0440 - learning_rate: 2.5000e-04
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1071 - ordering_loss: 0.7059 - reconstruction_loss: 0.0365 - reconstruction_mae: 0.0365
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1076 - ordering_loss: 0.7087 - reconstruction_loss: 0.0367 - reconstruction_mae: 0.0367 - val_loss: 0.1262 - val_ordering_loss: 0.8250 - val_reconstruction_loss: 0.0439 - val_reconstruction_mae: 0.0438 - learning_rate: 2.5000e-04
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1055 - ordering_loss: 0.6971 - reconstruction_loss: 0.0358 - reconstruction_mae: 0.0358 - val_loss: 0.1245 - val_ordering_loss: 0.8138 - val_reconstruction_loss: 0.0430 - val_reconstruction_mae: 0.0431 - learning_rate: 1.2500e-04
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1047 - ordering_loss: 0.6930 - reconstruction_loss: 0.0354 - reconstruction_mae: 0.0354 - val_loss: 0.1255 - val_ordering_loss: 0.8222 - val_reconstruction_loss: 0.0433 - val_reconstruction_mae: 0.0433 - learning_rate: 1.2500e-04
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1047 - ordering_loss: 0.6934 - reconstruction_loss: 0.0354 - reconstruction_mae: 0.0354 - val_loss: 0.1242 - val_ordering_loss: 0.8136 - val_reconstruction_loss: 0.0430 - val_reconstruction_mae: 0.0429 - learning_rate: 1.2500e-04
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1042 - ordering_loss: 0.6903 - reconstruction_loss: 0.0352 - reconstruction_mae: 0.0352 - val_loss: 0.1243 - val_ordering_loss: 0.8126 - val_reconstruction_loss: 0.0429 - val_reconstruction_mae: 0.0430 - learning_rate: 1.2500e-04
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1040 - ordering_loss: 0.6895 - reconstruction_loss: 0.0351 - reconstruction_mae: 0.0351 - val_loss: 0.1248 - val_ordering_loss: 0.8182 - val_reconstruction_loss: 0.0430 - val_reconstruction_mae: 0.0430 - learning_rate: 1.2500e-04
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1038 - ordering_loss: 0.6888 - reconstruction_loss: 0.0349 - reconstruction_mae: 0.0349
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1039 - ordering_loss: 0.6889 - reconstruction_loss: 0.0350 - reconstruction_mae: 0.0350 - val_loss: 0.1254 - val_ordering_loss: 0.8226 - val_reconstruction_loss: 0.0432 - val_reconstruction_mae: 0.0432 - learning_rate: 1.2500e-04
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1027 - ordering_loss: 0.6824 - reconstruction_loss: 0.0345 - reconstruction_mae: 0.0345 - val_loss: 0.1243 - val_ordering_loss: 0.8163 - val_reconstruction_loss: 0.0428 - val_reconstruction_mae: 0.0427 - learning_rate: 6.2500e-05
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1028 - ordering_loss: 0.6829 - reconstruction_loss: 0.0345 - reconstruction_mae: 0.0345 - val_loss: 0.1241 - val_ordering_loss: 0.8146 - val_reconstruction_loss: 0.0426 - val_reconstruction_mae: 0.0427 - learning_rate: 6.2500e-05
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1024 - ordering_loss: 0.6807 - reconstruction_loss: 0.0343 - reconstruction_mae: 0.0343 - val_loss: 0.1241 - val_ordering_loss: 0.8160 - val_reconstruction_loss: 0.0426 - val_reconstruction_mae: 0.0426 - learning_rate: 6.2500e-05
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 152ms/step - loss: 0.1023 - ordering_loss: 0.6801 - reconstruction_loss: 0.0343 - reconstruction_mae: 0.0343 - val_loss: 0.1245 - val_ordering_loss: 0.8176 - val_reconstruction_loss: 0.0428 - val_reconstruction_mae: 0.0428 - learning_rate: 6.2500e-05
# Epoch 59/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1022 - ordering_loss: 0.6793 - reconstruction_loss: 0.0342 - reconstruction_mae: 0.0342 - val_loss: 0.1244 - val_ordering_loss: 0.8164 - val_reconstruction_loss: 0.0427 - val_reconstruction_mae: 0.0427 - learning_rate: 6.2500e-05
# Epoch 60/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1018 - ordering_loss: 0.6772 - reconstruction_loss: 0.0341 - reconstruction_mae: 0.0341
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 194s 155ms/step - loss: 0.1021 - ordering_loss: 0.6787 - reconstruction_loss: 0.0342 - reconstruction_mae: 0.0342 - val_loss: 0.1240 - val_ordering_loss: 0.8136 - val_reconstruction_loss: 0.0427 - val_reconstruction_mae: 0.0426 - learning_rate: 6.2500e-05
# Epoch 61/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 152ms/step - loss: 0.1016 - ordering_loss: 0.6763 - reconstruction_loss: 0.0340 - reconstruction_mae: 0.0340 - val_loss: 0.1238 - val_ordering_loss: 0.8139 - val_reconstruction_loss: 0.0425 - val_reconstruction_mae: 0.0425 - learning_rate: 3.1250e-05
# Epoch 62/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 202s 152ms/step - loss: 0.1015 - ordering_loss: 0.6763 - reconstruction_loss: 0.0339 - reconstruction_mae: 0.0339 - val_loss: 0.1241 - val_ordering_loss: 0.8136 - val_reconstruction_loss: 0.0426 - val_reconstruction_mae: 0.0426 - learning_rate: 3.1250e-05
# Epoch 63/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1013 - ordering_loss: 0.6741 - reconstruction_loss: 0.0339 - reconstruction_mae: 0.0339 - val_loss: 0.1241 - val_ordering_loss: 0.8152 - val_reconstruction_loss: 0.0425 - val_reconstruction_mae: 0.0426 - learning_rate: 3.1250e-05
# Epoch 64/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.1012 - ordering_loss: 0.6742 - reconstruction_loss: 0.0338 - reconstruction_mae: 0.0338
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1013 - ordering_loss: 0.6750 - reconstruction_loss: 0.0338 - reconstruction_mae: 0.0338 - val_loss: 0.1239 - val_ordering_loss: 0.8130 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0425 - learning_rate: 3.1250e-05
# Epoch 65/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1010 - ordering_loss: 0.6731 - reconstruction_loss: 0.0337 - reconstruction_mae: 0.0337 - val_loss: 0.1239 - val_ordering_loss: 0.8145 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0425 - learning_rate: 1.5625e-05
# Epoch 66/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 152ms/step - loss: 0.1011 - ordering_loss: 0.6734 - reconstruction_loss: 0.0337 - reconstruction_mae: 0.0337 - val_loss: 0.1239 - val_ordering_loss: 0.8143 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.5625e-05
# Epoch 67/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1007 - ordering_loss: 0.6718 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335
# Epoch 67: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 190s 152ms/step - loss: 0.1010 - ordering_loss: 0.6734 - reconstruction_loss: 0.0337 - reconstruction_mae: 0.0337 - val_loss: 0.1239 - val_ordering_loss: 0.8152 - val_reconstruction_loss: 0.0425 - val_reconstruction_mae: 0.0425 - learning_rate: 1.5625e-05
# Epoch 68/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1008 - ordering_loss: 0.6717 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336 - val_loss: 0.1238 - val_ordering_loss: 0.8140 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 7.8125e-06
# Epoch 69/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1007 - ordering_loss: 0.6714 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336 - val_loss: 0.1238 - val_ordering_loss: 0.8131 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 7.8125e-06
# Epoch 70/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1010 - ordering_loss: 0.6738 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1009 - ordering_loss: 0.6724 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336 - val_loss: 0.1238 - val_ordering_loss: 0.8132 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 7.8125e-06
# Epoch 71/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 152ms/step - loss: 0.1008 - ordering_loss: 0.6721 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336 - val_loss: 0.1239 - val_ordering_loss: 0.8143 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 3.9063e-06
# Epoch 72/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1006 - ordering_loss: 0.6713 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8145 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 3.9063e-06
# Epoch 73/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 0.1004 - ordering_loss: 0.6693 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1007 - ordering_loss: 0.6712 - reconstruction_loss: 0.0336 - reconstruction_mae: 0.0336 - val_loss: 0.1239 - val_ordering_loss: 0.8142 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 3.9063e-06
# Epoch 74/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1005 - ordering_loss: 0.6700 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8151 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.9531e-06
# Epoch 75/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1007 - ordering_loss: 0.6715 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8138 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.9531e-06
# Epoch 76/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.1005 - ordering_loss: 0.6702 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1005 - ordering_loss: 0.6703 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8144 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.9531e-06
# Epoch 77/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1006 - ordering_loss: 0.6707 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8142 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 78/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1006 - ordering_loss: 0.6713 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8144 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 79/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 194s 156ms/step - loss: 0.1006 - ordering_loss: 0.6707 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8136 - val_reconstruction_loss: 0.0423 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 80/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1005 - ordering_loss: 0.6706 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8145 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 81/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 196s 157ms/step - loss: 0.1007 - ordering_loss: 0.6715 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8138 - val_reconstruction_loss: 0.0423 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 82/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 191s 153ms/step - loss: 0.1007 - ordering_loss: 0.6715 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1238 - val_ordering_loss: 0.8143 - val_reconstruction_loss: 0.0423 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 83/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 192s 154ms/step - loss: 0.1006 - ordering_loss: 0.6713 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8151 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 84/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 192s 153ms/step - loss: 0.1007 - ordering_loss: 0.6715 - reconstruction_loss: 0.0335 - reconstruction_mae: 0.0335 - val_loss: 0.1239 - val_ordering_loss: 0.8157 - val_reconstruction_loss: 0.0424 - val_reconstruction_mae: 0.0424 - learning_rate: 1.0000e-06
# Epoch 84: early stopping
# Restoring model weights from the end of the best epoch: 79.

# %% [markdown]
# Plotting of Result

# %%
def plot_training_history(history):
    fig, axes = plt.subplots(1, 2, figsize=(18, 5))

    # Reconstruction MAE
    axes[0].plot(
        history.history['reconstruction_mae'],     label='Train MAE')
    axes[0].plot(
        history.history['val_reconstruction_mae'], label='Val MAE')
    axes[0].set_title('Reconstruction MAE')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('MAE')
    axes[0].legend()
    axes[0].grid(True)

    # Ordering loss
    axes[1].plot(
        history.history['ordering_loss'],     label='Train')
    axes[1].plot(
        history.history['val_ordering_loss'], label='Val')
    axes[1].set_title('Ordering Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()
    axes[1].grid(True)

    plt.tight_layout()
    plt.savefig('training_curves.png', dpi=150)
    plt.show()

plot_training_history(history)

# %% [markdown]
# MAE per image

# %%
# Store per-image MAE
per_image_mae = []

for i in range(len(test_generator)):
    X_batch, Y_batch = test_generator.__getitem__(i)

    preds      = model.predict(X_batch, verbose=0)
    pred_image = preds['reconstruction']        # (B, 96, 96, 3)
    true_image = Y_batch['reconstruction']      # (B, 96, 96, 3)

    # MAE per image: mean over H, W, C axes → one number per image
    batch_mae = np.mean(
        np.abs(pred_image - true_image),
        axis=(1, 2, 3))                         # shape: (B,)

    per_image_mae.extend(batch_mae.tolist())

per_image_mae = np.array(per_image_mae)        # shape: (10000,)

test_mae = np.mean(per_image_mae)
test_std = np.std(per_image_mae)

print(f'Test MAE              : {test_mae:.4f}')
print(f'Test Std              : {test_std:.4f}')
# Out:
# Test MAE              : 0.0428
# Test Std              : 0.0378

# %% [markdown]
# MAE per batch

# %%
mae = tf.keras.metrics.MeanAbsoluteError()

mae_values = []

for i in range(len(test_generator)):
    X_batch, Y_batch = test_generator.__getitem__(i)

    pred = model.predict(X_batch, verbose=0)['reconstruction']
    true = Y_batch['reconstruction']

    # IMPORTANT: reset state per batch (otherwise it accumulates incorrectly)
    mae.reset_state()

    mae.update_state(true, pred)

    mae_values.append(mae.result().numpy())

test_mae = tf.reduce_mean(mae_values)
test_std = tf.math.reduce_std(mae_values)

print("MAE:", test_mae.numpy())
print("STD:", test_std.numpy())
# Out:
# MAE: 0.042719778
# STD: 0.0055286437

# %%
def visualize_results(model, generator, n_samples=4):
    X_batch, Y_batch = generator.__getitem__(1)
    preds            = model.predict(X_batch[:n_samples], verbose=0)
    pred_images      = preds['reconstruction']
    true_images      = Y_batch['reconstruction']

    fig, axes = plt.subplots(
        n_samples, 2, figsize=(12, 4 * n_samples))

    titles = ['Real', 'Reconstructed']

    for j, title in enumerate(titles):
        axes[0, j].set_title(title, fontsize=12, fontweight='bold')

    for i in range(n_samples):
        axes[i, 0].imshow(true_images[i])
        axes[i, 1].imshow(np.clip(pred_images[i], 0, 1))


        mae = np.mean(np.abs(pred_images[i] - true_images[i]))
        axes[i, 1].set_xlabel(f'MAE: {mae:.4f}', fontsize=10)

        for j in range(2):
            axes[i, j].axis('off')

    plt.tight_layout()
    plt.savefig('reconstruction_results.png', dpi=150)
    plt.show()

visualize_results(model, test_generator)

# %%
pl = model.get_layer('neural_placement')
print("Learned position_coords:")
print(np.round(pl.position_coords.numpy(), 4))
# Out:
# Learned position_coords:
# [[-6.736e-01 -6.737e-01]
#  [-6.736e-01 -0.000e+00]
#  [-6.736e-01  6.737e-01]
#  [ 1.000e-04 -6.737e-01]
#  [ 1.000e-04 -0.000e+00]
#  [ 1.000e-04  6.737e-01]
#  [ 6.738e-01 -6.737e-01]
#  [ 6.738e-01 -0.000e+00]
#  [ 6.738e-01  6.737e-01]]

# %%
WEIGHTS_PATH = 'jigsaw_weights_v3.weights.h5'
model.save_weights(WEIGHTS_PATH)
print(f'Weights saved: {WEIGHTS_PATH}')
# Out:
# Weights saved: jigsaw_weights_v3.weights.h5

# %%
def verify_weights(weights_path, test_generator):
    print('Building fresh model...')
    fresh_model, _ = build_full_pipeline()
    fresh_model.compile(
        optimizer = 'adam',
        loss      = {
            'reconstruction': 'mae',
            'ordering'      : ordering_loss
        },
        loss_weights = {'reconstruction': 1.0, 'ordering': 0.1},
        metrics      = {
            'reconstruction': keras.metrics.MeanAbsoluteError(name='mae')
        }
    )

    fresh_model.load_weights(weights_path)
    print('Weights loaded successfully!')

    # Fixed batch — same idx = same scramble = reproducible MAE
    X_check, Y_check = test_generator.__getitem__(0)
    preds            = fresh_model.predict(X_check, verbose=0)

    mae = np.mean(np.abs(
        preds['reconstruction'] - Y_check['reconstruction']))

    print(f'Verification MAE : {mae:.4f}')
    print(f'Output shape     : {preds["reconstruction"].shape}')
    print(f'Output range     : '
          f'[{preds["reconstruction"].min():.3f}, '
          f'{preds["reconstruction"].max():.3f}]')
    return mae

local_mae = verify_weights(WEIGHTS_PATH, test_generator)
# Out:
# Building fresh model...
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 324 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Weights loaded successfully!
# Verification MAE : 0.0510
# Output shape     : (64, 96, 96, 3)
# Output range     : [0.000, 1.000]

# %%
import gdown
# !gdown 1ZJqiacabj5B2uHDMgIOjyozpY7D6hM4V

fresh_model, _ = build_full_pipeline()
fresh_model.compile(optimizer='adam', loss='mae',
                    metrics=[keras.metrics.MeanAbsoluteError(name='mae')])

fresh_model.load_weights('jigsaw_weights_v3.weights.h5')
print('Weights loaded')

# Step 3: Compute downloaded MAE over full test set
per_image_mae = []
for i in range(len(test_generator)):
    X_batch, Y_batch = test_generator.__getitem__(i)
    pred      = fresh_model.predict(X_batch, verbose=0)
    batch_mae = np.mean(np.abs(pred['reconstruction'] - Y_batch['reconstruction']), axis=(1,2,3))
    per_image_mae.extend(batch_mae.tolist())

per_image_mae  = np.array(per_image_mae)
downloaded_mae = np.mean(per_image_mae)
downloaded_std = np.std(per_image_mae)

print(f'Downloaded Model — Test MAE : {downloaded_mae:.4f}')
print(f'Downloaded Model — Test Std : {downloaded_std:.4f}')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZJqiacabj5B2uHDMgIOjyozpY7D6hM4V
# To: /content/jigsaw_weights_v3.weights.h5
# 100% 26.1M/26.1M [00:01<00:00, 25.3MB/s]
# Weights loaded
# Downloaded Model — Test MAE : 0.0428
# Downloaded Model — Test Std : 0.0378

# %% [markdown]
# BASELINE

# %%
def mean_patch_image(patches):
    #input (B,9,28,28,3)
    B = tf.shape(patches)[0] # Corrected: Use batch size from patches input
    # Mean patch
    mean_patch = tf.reduce_mean(patches, axis=1)  # (B, 28, 28, 3)
    # Replicate 9 times
    mean_patches = tf.repeat(
        mean_patch[:, None, :, :, :],
        repeats=9,
        axis=1
    )
    # Reassemble into 96x96 image
    out = tf.reshape(mean_patches, (B, 3, 3, 28, 28, 3))
    out = tf.transpose(out, [0, 1, 3, 2, 4, 5])
    out = tf.reshape(out, (B, 84, 84, 3))
    out = tf.image.resize(out, (96, 96))
    return out

# %%
#compute MAE for mean_patch_image using the test_generator
mae = tf.keras.metrics.MeanAbsoluteError()
mae_values = []
for i in range(len(test_generator)):
    a,b = test_generator.__getitem__(i)
    pred = mean_patch_image(a)
    mae_values.append(mae(pred,b['reconstruction']))
print("MAE:", tf.reduce_mean(mae_values))
print("std:", tf.math.reduce_std(mae_values))
# Out:
# MAE: tf.Tensor(0.18193913, shape=(), dtype=float32)
# std: tf.Tensor(0.00094474753, shape=(), dtype=float32)

# %%
def visualize_baseline_results(generator, n_samples=4):
    X_batch, Y_batch = generator.__getitem__(4)

    # Generate predictions using the mean_patch_image function for the baseline
    pred_images = mean_patch_image(X_batch[:n_samples])
    true_images = Y_batch['reconstruction'][:n_samples]

    fig, axes = plt.subplots(
        n_samples, 2, figsize=(12, 4 * n_samples))

    titles = ['Real', 'Baseline Reconstruction']

    for j, title in enumerate(titles):
        axes[0, j].set_title(title, fontsize=12, fontweight='bold')

    for i in range(n_samples):
        axes[i, 0].imshow(true_images[i])
        axes[i, 1].imshow(np.clip(pred_images[i], 0, 1))

        mae = np.mean(np.abs(pred_images[i] - true_images[i]))
        axes[i, 1].set_xlabel(f'MAE: {mae:.4f}', fontsize=10)

        for j in range(2):
            axes[i, j].axis('off')

    plt.tight_layout()
    plt.savefig('baseline_reconstruction_results.png', dpi=150)
    plt.show()

visualize_baseline_results(test_generator)

# %% [markdown]
# # Additional Constraints
#
# * The solution must rely entirely on neural networks and must not contain non-neural algorithmic components. A pipeline of neural networks is allowed.
# * Pretrained models are not permitted.
# * The total number of trainable parameters must remain below 6 million. The number of parameters of the proposed solution must be reported explicitly.
# * The model weights must be made available for download via gdown. Please verify that the provided link works correctly and that the weights can be loaded successfully.
# * The solution must be implemented in Keras and must run on Google Colab. Submissions containing notebook execution errors will be penalized.
# * The submission must be a single, well documented notebook file. Tar files will be rejected.
